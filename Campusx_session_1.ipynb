# %%
a = 1
b = 2
print("SUM of A and B : ",c)
c = a + b

type(c)
# Out:
# SUM of A and B :  3
# int

# %%
print("Hello world")
# Out:
# Hello world

# %%
print(1,2,3,4,5,sep=',')
# Out:
# 1,2,3,4,5

# %%
fnum = int(input("Enter Your 1st Number: "))
snum = int(input("Enter Your 2nd Numb10er: "))
result = fnum + snum
print(result)
print(type(fnum))
# Out:
# 20
# <class 'int'>

# %%
# program practise 1
Name = "AYUSH RATAN"
Age  = "22"
Course_Name = "MCA(Hons)-Data Science"
print("Student INFO: ")
print(Name, end="\n")
print(Age, end="\n")
print(Course_Name, end="\n")
# Out:
# Student INFO:
# AYUSH RATAN
# 22
# MCA(Hons)-Data Science

# %%
# program Practise 2
Name = input("Enter Your Name : ")
Age = input("Enter Your Age : ")
print("This is user info: ", Name,Age,sep=",")
# Out:
# This is user info: ,AYUSH,10

# %%
# program peactise 3. we take a 2 numbers input from user we print a sum of these number  but input type is string 
fnum = input("Enter your 1st number : ")
snum = input("Enter Your 2nd Number : ")
result = int(fnum) + int(snum)
print(result)
type(fnum)
type(snum)
# Out:
# 5
# str

# %%
#program practise 4 . we take input from user and print the user fav number
user = int(input("Enter your fav Number : "))
print("This is your Fav NUmber: ", user)
# Out:
# This is your Fav NUmber:  3

# %%
# program Practise 5 . we make a 3 veriable . we print the number and display the type 
city = input("Enter Your city name : ")
Pincode = int(input("Enter Your curent Pincode : "))
Population = input("Enter The Population of you city : ")
print(city,Pincode,Population,sep=",")
print(type(city))
print(type(Pincode))
print(type(Population))
# Out:
# Ayodhya,224182,2568985584
# <class 'str'>
# <class 'int'>
# <class 'str'>

# %%
# program practise 6. we take a 2 decimal number from user and print sum and print type of result .\
f = input("Enter Your 1st Number : ")
s = input("Enter Your 2nd Number : ")
result = float(f) + float(s)
print(result)
print(type(result))
# Out:
# 2.6
# <class 'float'>

# %%
# this program practise 7 . we take a name of user and calculate a length of the name 
name = input("enter your name : ")
print("This is a your name : ",name)
print("This your name length : ", len(name) )
# Out:
# This is a your name :  Ayush
# This your name length :  5

# %%
# this program practis 8. we take a age as a input from user and just calculate a age after 10 years
age  = input("Enter your age : ")
result = int(age) + 10
print("This is your age after 10 years : ", result)
# Out:
# This is your age after 10 years :  32
