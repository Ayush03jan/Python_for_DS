# %%
# Create variables
a = 10
b = 5
# Print modulus
print(a%b)
# Print floor division
print(a//b)
# Print power
print(5 ** 3)
# Add 10 to a
a += 10
print(a)
# Out:
# 0
# 2
# 125
# 20

# %%
# this is a If-else statement condition this use for decision making in program 
age = int(input("Enter Your Current Age : "))
name  = str(input("Enter Your Name : "))
if(age >= 18):
    print("Your Eligible For Voting...", name)
else:
    print("You are not eligible for voting....", name )
# Out:
# You are not eligible for voting.... Ayush

# %%
print("HELLO WORLD")
